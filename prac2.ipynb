# %% [markdown]
# # Practical 2
# ## Apply preprocessing steps on the selected Dataset.

# %%
import re 
import pandas as pd
import string as strs
import nlp_lib #https://github.com/Sh1vam/nlp_lib
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nlp_lib import *
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.corpus import wordnet

# %%
df=pd.read_csv("IMDBDS.csv")

# %%
df.head()
# Out:
#                                               review sentiment
# 0  https://github.com/Sh1vam One of the other rev...  positive
# 1  A wonderful little production. <br />https://g...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# ### Lower Casing

# %%
df['review']=df['review'].str.lower()

# %%
df.head()
# Out:
#                                               review sentiment
# 0  https://github.com/sh1vam one of the other rev...  positive
# 1  a wonderful little production. <br />https://g...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %% [markdown]
# ### Removing HTML Tags

# %%
def remove_html_tags(text):
    if isinstance(text, str):  # Check if the input is a string
        reg = re.compile(r"<[^>]*>")  # Regular expression to match HTML tags
        return reg.sub('', text)  # Remove HTML tags
    else:
        return text
df['review']=df['review'].apply(remove_html_tags)
df.head()
# Out:
#                                               review sentiment
# 0  https://github.com/sh1vam one of the other rev...  positive
# 1  a wonderful little production. https://github....  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %% [markdown]
# ### Removing URLs

# %%
def remove_url(text):
  if isinstance(text, str):
    url_pattern = re.compile(r"(http?|ftp|https?|file)://\S+ ")
    return re.sub(url_pattern, "", text)
  else:
    return text
df['review']=df['review'].apply(remove_url)
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. filming techniq...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %% [markdown]
# ### Removing Punctuations

# %%
def remove_punctuations(text):
  if pd.isnull(text):  
        return np.nan
  text = text.translate(str.maketrans('', '', strs.punctuation))
  return text.strip()
df['review']=df['review'].apply(remove_punctuations)
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production filming techniqu...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive

# %% [markdown]
# ### Removing Special Characters

# %%
def removes_specials(text):
  tmp=text
  if pd.isnull(tmp):  
        return np.nan
  pattern = re.compile(r'[A-Za-z0-9\s]')
  specials = re.sub(pattern, "", tmp)
  return text.translate(str.maketrans('', '', specials)).strip()
df['review']=df['review'].apply(removes_specials)
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production filming techniqu...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive

# %% [markdown]
# ### Removing Non-Printable Characters

# %%
def removes_non_printables(text):
  tmp=text
  if pd.isnull(tmp):  
        return np.nan
  specials = tmp.translate(str.maketrans('', '', strs.printable)).strip()
  return text.translate(str.maketrans('', '', specials)).strip()
df['review']=df['review'].apply(removes_non_printables)
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production filming techniqu...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive

# %% [markdown]
# ### Defining English Corpus

# %%
stop_words = set(stopwords.words('english'))

# %% [markdown]
# ### Removing Stop Words

# %%
def remove_stopwords(text):
    if pd.isnull(text):  
        return np.nan
    tokens = text.split()
    filtered_words = [word for word in tokens if word not in stop_words]
    return ' '.join(filtered_words)
df['stopwords_removed']=df['review'].apply(remove_stopwords)
df.head()
# Out:
#                                               review sentiment  \
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production filming techniqu...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive
#
#                                    stopwords_removed
# 0  one reviewers mentioned watching 1 oz episode ...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically theres family little boy jake thinks...
# 4  petter matteis love time money visually stunni...

# %% [markdown]
# ### Text Tokenization

# %%
def tokenized_text(text):
    if pd.isnull(text):  
        return np.nan
    return nltk.word_tokenize(text)
df['tokenized']=df['stopwords_removed'].apply(tokenized_text)
df.head()
# Out:
#                                               review sentiment  \
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production filming techniqu...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive
#
#                                    stopwords_removed  \
# 0  one reviewers mentioned watching 1 oz episode ...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically theres family little boy jake thinks...
# 4  petter matteis love time money visually stunni...
#
#                                            tokenized
# 0  [one, reviewers, mentioned, watching, 1, oz, e...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, wonderful, way, spend, time, hot, su...
# 3  [basically, theres, family, little, boy, jake,...
# 4  [petter, matteis, love, time, money, visually,...

# %% [markdown]
# ### Implementing PorterStemmer to do stemming

# %%
ps = PorterStemmer()
def porter_stemming(tokenised_text):
    if isinstance(tokenised_text, list):  # Check if it's a list
        return [ps.stem(word) for word in tokenised_text]  # Apply stemming word by word
    else:
        return np.nan 
df['porter_stemmed']=df['tokenized'].apply(porter_stemming)
df.head()
# Out:
#                                               review sentiment  \
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production filming techniqu...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive
#
#                                    stopwords_removed  \
# 0  one reviewers mentioned watching 1 oz episode ...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically theres family little boy jake thinks...
# 4  petter matteis love time money visually stunni...
#
#                                            tokenized  \
# 0  [one, reviewers, mentioned, watching, 1, oz, e...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, wonderful, way, spend, time, hot, su...
# 3  [basically, theres, family, little, boy, jake,...
# 4  [petter, matteis, love, time, money, visually,...
#
#                                       porter_stemmed
# 0  [one, review, mention, watch, 1, oz, episod, y...
# 1  [wonder, littl, product, film, techniqu, unass...
# 2  [thought, wonder, way, spend, time, hot, summe...
# 3  [basic, there, famili, littl, boy, jake, think...
# 4  [petter, mattei, love, time, money, visual, st...

# %% [markdown]
# ### Applying Other Stemming Functions

# %%
df['lancaster_stemmed']=df['tokenized'].apply(lancaster_stemming)
df.head()
# Out:
#                                               review sentiment  \
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production filming techniqu...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive
#
#                                    stopwords_removed  \
# 0  one reviewers mentioned watching 1 oz episode ...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically theres family little boy jake thinks...
# 4  petter matteis love time money visually stunni...
#
#                                            tokenized  \
# 0  [one, reviewers, mentioned, watching, 1, oz, e...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, wonderful, way, spend, time, hot, su...
# 3  [basically, theres, family, little, boy, jake,...
# 4  [petter, matteis, love, time, money, visually,...
#
#                                       porter_stemmed  \
# 0  [one, review, mention, watch, 1, oz, episod, y...
# 1  [wonder, littl, product, film, techniqu, unass...
# 2  [thought, wonder, way, spend, time, hot, summe...
# 3  [basic, there, famili, littl, boy, jake, think...
# 4  [petter, mattei, love, time, money, visual, st...
#
#                                    lancaster_stemmed
# 0  [on, review, ment, watch, 1, oz, episod, youl,...
# 1  [wond, littl, produc, film, techn, unassum, ol...
# 2  [thought, wond, way, spend, tim, hot, sum, wee...
# 3  [bas, ther, famy, littl, boy, jak, think, ther...
# 4  [pet, mat, lov, tim, money, vis, stun, film, w...

# %%
df['snowball_stemming']=df['tokenized'].apply(snowball_stemming)
df.head()
# Out:
#                                               review sentiment  \
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production filming techniqu...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive
#
#                                    stopwords_removed  \
# 0  one reviewers mentioned watching 1 oz episode ...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically theres family little boy jake thinks...
# 4  petter matteis love time money visually stunni...
#
#                                            tokenized  \
# 0  [one, reviewers, mentioned, watching, 1, oz, e...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, wonderful, way, spend, time, hot, su...
# 3  [basically, theres, family, little, boy, jake,...
# 4  [petter, matteis, love, time, money, visually,...
#
#                                       porter_stemmed  \
# 0  [one, review, mention, watch, 1, oz, episod, y...
# 1  [wonder, littl, product, film, techniqu, unass...
# 2  [thought, wonder, way, spend, time, hot, summe...
# 3  [basic, there, famili, littl, boy, jake, think...
# 4  [petter, mattei, love, time, money, visual, st...
#
#                                    lancaster_stemmed  \
# 0  [on, review, ment, watch, 1, oz, episod, youl,...
# 1  [wond, littl, produc, film, techn, unassum, ol...
# 2  [thought, wond, way, spend, tim, hot, sum, wee...
# 3  [bas, ther, famy, littl, boy, jak, think, ther...
# 4  [pet, mat, lov, tim, money, vis, stun, film, w...
#
#                                    snowball_stemming
# 0  [one, review, mention, watch, 1, oz, episod, y...
# 1  [wonder, littl, product, film, techniqu, unass...
# 2  [thought, wonder, way, spend, time, hot, summe...
# 3  [basic, there, famili, littl, boy, jake, think...
# 4  [petter, mattei, love, time, money, visual, st...

# %%
df['regexp_stemmed']=df['tokenized'].apply(regexp_stemming)
df.head()
# Out:
#                                               review sentiment  \
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production filming techniqu...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive
#
#                                    stopwords_removed  \
# 0  one reviewers mentioned watching 1 oz episode ...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically theres family little boy jake thinks...
# 4  petter matteis love time money visually stunni...
#
#                                            tokenized  \
# 0  [one, reviewers, mentioned, watching, 1, oz, e...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, wonderful, way, spend, time, hot, su...
# 3  [basically, theres, family, little, boy, jake,...
# 4  [petter, matteis, love, time, money, visually,...
#
#                                       porter_stemmed  \
# 0  [one, review, mention, watch, 1, oz, episod, y...
# 1  [wonder, littl, product, film, techniqu, unass...
# 2  [thought, wonder, way, spend, time, hot, summe...
# 3  [basic, there, famili, littl, boy, jake, think...
# 4  [petter, mattei, love, time, money, visual, st...
#
#                                    lancaster_stemmed  \
# 0  [on, review, ment, watch, 1, oz, episod, youl,...
# 1  [wond, littl, produc, film, techn, unassum, ol...
# 2  [thought, wond, way, spend, tim, hot, sum, wee...
# 3  [bas, ther, famy, littl, boy, jak, think, ther...
# 4  [pet, mat, lov, tim, money, vis, stun, film, w...
#
#                                    snowball_stemming  \
# 0  [one, review, mention, watch, 1, oz, episod, y...
# 1  [wonder, littl, product, film, techniqu, unass...
# 2  [thought, wonder, way, spend, time, hot, summe...
# 3  [basic, there, famili, littl, boy, jake, think...
# 4  [petter, mattei, love, time, money, visual, st...
#
#                                       regexp_stemmed
# 0  [one, reviewer, mentioned, watch, 1, oz, episo...
# 1  [wonderful, littl, production, film, techniqu,...
# 2  [thought, wonderful, way, spend, tim, hot, sum...
# 3  [basically, there, family, littl, boy, jak, th...
# 4  [petter, mattei, lov, tim, money, visually, st...

# %% [markdown]
# ### Applying Lemmatization using WordNetLemmatizer

# %%
lemmatizer= WordNetLemmatizer()
def wordnet_lemmatizing(tokenised_text):
    if isinstance(tokenised_text, list):  
        return [lemmatizer.lemmatize(word) for word in tokenised_text]  
    else:
        return np.nan 
df['lemmatized']=df['tokenized'].apply(wordnet_lemmatizing)
df.head()
# Out:
#                                               review sentiment  \
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production filming techniqu...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive
#
#                                    stopwords_removed  \
# 0  one reviewers mentioned watching 1 oz episode ...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically theres family little boy jake thinks...
# 4  petter matteis love time money visually stunni...
#
#                                            tokenized  \
# 0  [one, reviewers, mentioned, watching, 1, oz, e...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, wonderful, way, spend, time, hot, su...
# 3  [basically, theres, family, little, boy, jake,...
# 4  [petter, matteis, love, time, money, visually,...
#
#                                       porter_stemmed  \
# 0  [one, review, mention, watch, 1, oz, episod, y...
# 1  [wonder, littl, product, film, techniqu, unass...
# 2  [thought, wonder, way, spend, time, hot, summe...
# 3  [basic, there, famili, littl, boy, jake, think...
# 4  [petter, mattei, love, time, money, visual, st...
#
#                                    lancaster_stemmed  \
# 0  [on, review, ment, watch, 1, oz, episod, youl,...
# 1  [wond, littl, produc, film, techn, unassum, ol...
# 2  [thought, wond, way, spend, tim, hot, sum, wee...
# 3  [bas, ther, famy, littl, boy, jak, think, ther...
# 4  [pet, mat, lov, tim, money, vis, stun, film, w...
#
#                                    snowball_stemming  \
# 0  [one, review, mention, watch, 1, oz, episod, y...
# 1  [wonder, littl, product, film, techniqu, unass...
# 2  [thought, wonder, way, spend, time, hot, summe...
# 3  [basic, there, famili, littl, boy, jake, think...
# 4  [petter, mattei, love, time, money, visual, st...
#
#                                       regexp_stemmed  \
# 0  [one, reviewer, mentioned, watch, 1, oz, episo...
# 1  [wonderful, littl, production, film, techniqu,...
# 2  [thought, wonderful, way, spend, tim, hot, sum...
# 3  [basically, there, family, littl, boy, jak, th...
# 4  [petter, mattei, lov, tim, money, visually, st...
#
#                                           lemmatized
# 0  [one, reviewer, mentioned, watching, 1, oz, ep...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, wonderful, way, spend, time, hot, su...
# 3  [basically, there, family, little, boy, jake, ...
# 4  [petter, matteis, love, time, money, visually,...

# %%
df['procss']=df['lemmatized'].apply(removes_specials)

# %%
df.to_csv("reviews.csv",index=False)

# %%
df=pd.read_csv("reviews.csv")

# %%
df.head()
# Out:
#                                               review sentiment  \
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production filming techniqu...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive
#
#                                    stopwords_removed  \
# 0  one reviewers mentioned watching 1 oz episode ...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically theres family little boy jake thinks...
# 4  petter matteis love time money visually stunni...
#
#                                            tokenized  \
# 0  ['one', 'reviewers', 'mentioned', 'watching', ...
# 1  ['wonderful', 'little', 'production', 'filming...
# 2  ['thought', 'wonderful', 'way', 'spend', 'time...
# 3  ['basically', 'theres', 'family', 'little', 'b...
# 4  ['petter', 'matteis', 'love', 'time', 'money',...
#
#                                       porter_stemmed  \
# 0  ['one', 'review', 'mention', 'watch', '1', 'oz...
# 1  ['wonder', 'littl', 'product', 'film', 'techni...
# 2  ['thought', 'wonder', 'way', 'spend', 'time', ...
# 3  ['basic', 'there', 'famili', 'littl', 'boy', '...
# 4  ['petter', 'mattei', 'love', 'time', 'money', ...
#
#                                    lancaster_stemmed  \
# 0  ['on', 'review', 'ment', 'watch', '1', 'oz', '...
# 1  ['wond', 'littl', 'produc', 'film', 'techn', '...
# 2  ['thought', 'wond', 'way', 'spend', 'tim', 'ho...
# 3  ['bas', 'ther', 'famy', 'littl', 'boy', 'jak',...
# 4  ['pet', 'mat', 'lov', 'tim', 'money', 'vis', '...
#
#                                    snowball_stemming  \
# 0  ['one', 'review', 'mention', 'watch', '1', 'oz...
# 1  ['wonder', 'littl', 'product', 'film', 'techni...
# 2  ['thought', 'wonder', 'way', 'spend', 'time', ...
# 3  ['basic', 'there', 'famili', 'littl', 'boy', '...
# 4  ['petter', 'mattei', 'love', 'time', 'money', ...
#
#                                       regexp_stemmed  \
# 0  ['one', 'reviewer', 'mentioned', 'watch', '1',...
# 1  ['wonderful', 'littl', 'production', 'film', '...
# 2  ['thought', 'wonderful', 'way', 'spend', 'tim'...
# 3  ['basically', 'there', 'family', 'littl', 'boy...
# 4  ['petter', 'mattei', 'lov', 'tim', 'money', 'v...
#
#                                           lemmatized  \
# 0  ['one', 'reviewer', 'mentioned', 'watching', '...
# 1  ['wonderful', 'little', 'production', 'filming...
# 2  ['thought', 'wonderful', 'way', 'spend', 'time...
# 3  ['basically', 'there', 'family', 'little', 'bo...
# 4  ['petter', 'matteis', 'love', 'time', 'money',...
#
#                                               procss
# 0  one reviewer mentioned watching 1 oz episode y...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically there family little boy jake think t...
# 4  petter matteis love time money visually stunni...

# %%
wordnet_map={"N": wordnet.NOUN, "V": wordnet.VERB, "J": wordnet.ADJ, "R": wordnet.ADV}
def get_wordnet_pos(tag):
    if pd.isnull(tag):  
        return np.nan
    if tag.startswith('J'):
        return wordnet.ADJ  # adjective
    elif tag.startswith('V'):
        return wordnet.VERB  # verb
    elif tag.startswith('N'):
        return wordnet.NOUN  # noun
    elif tag.startswith('R'):
        return wordnet.ADV  # adverb
    else:
        return wordnet.NOUN  # default to noun

# %%
wnl = WordNetLemmatizer()
def word_pos_tag(text):
    if pd.isnull(text):  
        return np.nan
    # Tokenize the text
    tokens = re.split(r'\W+', text)
    # Remove stopwords
    text = [word for word in tokens if word not in stopwords.words('english')]
    # Lemmatize the text
    text_lemmatized = [wnl.lemmatize(word) for word in text]
    # Perform POS tagging
    pos_tags = nltk.pos_tag(text_lemmatized)
    return pos_tags 
    # return text  # This line is unreachable and can be removed

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\PCD\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
a=word_pos_tag(df["procss"][0])
a
# Out:
# [('one', 'CD'),
#  ('reviewer', 'NN'),
#  ('mentioned', 'VBD'),
#  ('watching', 'VBG'),
#  ('1', 'CD'),
#  ('oz', 'JJ'),
#  ('episode', 'NN'),
#  ('youll', 'NN'),
#  ('hooked', 'VBD'),
#  ('right', 'RB'),
#  ('exactly', 'RB'),
#  ('happened', 'VBD'),
#  ('methe', 'NNS'),
#  ('first', 'JJ'),
#  ('thing', 'NN'),
#  ('struck', 'VBD'),
#  ('oz', 'JJ'),
#  ('brutality', 'NN'),
#  ('unflinching', 'VBG'),
#  ('scene', 'NN'),
#  ('violence', 'NN'),
#  ('set', 'VBN'),
#  ('right', 'RB'),
#  ('word', 'NN'),
#  ('go', 'VB'),
#  ('trust', 'NN'),
#  ('show', 'NN'),
#  ('faint', 'NN'),
#  ('hearted', 'VBD'),
#  ('timid', 'JJ'),
#  ('show', 'NN'),
#  ('pull', 'JJ'),
#  ('punch', 'JJ'),
#  ('regard', 'JJ'),
#  ('drug', 'NN'),
#  ('sex', 'NN'),
#  ('violence', 'NN'),
#  ('hardcore', 'NN'),
#  ('classic', 'JJ'),
#  ('use', 'NN'),
#  ('wordit', 'NN'),
#  ('called', 'VBN'),
#  ('oz', 'NN'),
#  ('nickname', 'NN'),
#  ('given', 'VBN'),
#  ('oswald', 'JJ'),
#  ('maximum', 'JJ'),
#  ('security', 'NN'),
#  ('state', 'NN'),
#  ('penitentary', 'JJ'),
#  ('focus', 'NN'),
#  ('mainly', 'RB'),
#  ('emerald', 'VBZ'),
#  ('city', 'NN'),
#  ('experimental', 'JJ'),
#  ('section', 'NN'),
#  ('prison', 'NN'),
#  ('cell', 'NN'),
#  ('glass', 'NN'),
#  ('front', 'JJ'),
#  ('face', 'NN'),
#  ('inwards', 'NNS'),
#  ('privacy', 'VBP'),
#  ('high', 'JJ'),
#  ('agenda', 'NN'),
#  ('em', 'VBP'),
#  ('city', 'NN'),
#  ('home', 'NN'),
#  ('manyaryans', 'NNS'),
#  ('muslim', 'VBP'),
#  ('gangsta', 'JJ'),
#  ('latino', 'NN'),
#  ('christian', 'JJ'),
#  ('italian', 'JJ'),
#  ('irish', 'JJ'),
#  ('moreso', 'NN'),
#  ('scuffle', 'VBD'),
#  ('death', 'NN'),
#  ('stare', 'NN'),
#  ('dodgy', 'VBZ'),
#  ('dealing', 'VBG'),
#  ('shady', 'JJ'),
#  ('agreement', 'NN'),
#  ('never', 'RB'),
#  ('far', 'RB'),
#  ('awayi', 'JJ'),
#  ('would', 'MD'),
#  ('say', 'VB'),
#  ('main', 'JJ'),
#  ('appeal', 'NN'),
#  ('show', 'NN'),
#  ('due', 'JJ'),
#  ('fact', 'NN'),
#  ('go', 'VB'),
#  ('show', 'NN'),
#  ('wouldnt', 'WRB'),
#  ('dare', 'NN'),
#  ('forget', 'VB'),
#  ('pretty', 'JJ'),
#  ('picture', 'NN'),
#  ('painted', 'VBN'),
#  ('mainstream', 'JJ'),
#  ('audience', 'NN'),
#  ('forget', 'NN'),
#  ('charm', 'NN'),
#  ('forget', 'NN'),
#  ('romanceoz', 'NN'),
#  ('doesnt', 'NN'),
#  ('mess', 'NN'),
#  ('around', 'IN'),
#  ('first', 'JJ'),
#  ('episode', 'NN'),
#  ('ever', 'RB'),
#  ('saw', 'VBD'),
#  ('struck', 'JJ'),
#  ('nasty', 'JJ'),
#  ('surreal', 'NN'),
#  ('couldnt', 'NNS'),
#  ('say', 'VBP'),
#  ('ready', 'JJ'),
#  ('watched', 'VBN'),
#  ('developed', 'JJ'),
#  ('taste', 'NN'),
#  ('oz', 'NN'),
#  ('got', 'VBD'),
#  ('accustomed', 'JJ'),
#  ('high', 'JJ'),
#  ('level', 'NN'),
#  ('graphic', 'JJ'),
#  ('violence', 'NN'),
#  ('violence', 'NN'),
#  ('injustice', 'NN'),
#  ('crooked', 'VBD'),
#  ('guard', 'NN'),
#  ('wholl', 'NN'),
#  ('sold', 'VBN'),
#  ('nickel', 'JJ'),
#  ('inmate', 'NN'),
#  ('wholl', 'NN'),
#  ('kill', 'NN'),
#  ('order', 'NN'),
#  ('get', 'VB'),
#  ('away', 'RB'),
#  ('well', 'RB'),
#  ('mannered', 'JJ'),
#  ('middle', 'JJ'),
#  ('class', 'NN'),
#  ('inmate', 'NN'),
#  ('turned', 'VBD'),
#  ('prison', 'JJ'),
#  ('bitch', 'NN'),
#  ('due', 'JJ'),
#  ('lack', 'NN'),
#  ('street', 'NN'),
#  ('skill', 'JJ'),
#  ('prison', 'NN'),
#  ('experience', 'NN'),
#  ('watching', 'VBG'),
#  ('oz', 'NN'),
#  ('may', 'MD'),
#  ('become', 'VB'),
#  ('comfortable', 'JJ'),
#  ('uncomfortable', 'JJ'),
#  ('viewingthats', 'NNS'),
#  ('get', 'VBP'),
#  ('touch', 'JJ'),
#  ('darker', 'NN'),
#  ('side', 'NN')]

# %%
b=get_wordnet_pos('JJ')
b
# Out:
# 'a'

# %%
pos_tag(df["procss"][0].split(" "))
# Out:
# [('one', 'CD'),
#  ('reviewer', 'NN'),
#  ('mentioned', 'VBD'),
#  ('watching', 'VBG'),
#  ('1', 'CD'),
#  ('oz', 'JJ'),
#  ('episode', 'NN'),
#  ('youll', 'NN'),
#  ('hooked', 'VBD'),
#  ('right', 'RB'),
#  ('exactly', 'RB'),
#  ('happened', 'VBD'),
#  ('methe', 'NNS'),
#  ('first', 'JJ'),
#  ('thing', 'NN'),
#  ('struck', 'VBD'),
#  ('oz', 'JJ'),
#  ('brutality', 'NN'),
#  ('unflinching', 'VBG'),
#  ('scene', 'NN'),
#  ('violence', 'NN'),
#  ('set', 'VBN'),
#  ('right', 'RB'),
#  ('word', 'NN'),
#  ('go', 'VB'),
#  ('trust', 'NN'),
#  ('show', 'NN'),
#  ('faint', 'NN'),
#  ('hearted', 'VBD'),
#  ('timid', 'JJ'),
#  ('show', 'NN'),
#  ('pull', 'JJ'),
#  ('punch', 'JJ'),
#  ('regard', 'JJ'),
#  ('drug', 'NN'),
#  ('sex', 'NN'),
#  ('violence', 'NN'),
#  ('hardcore', 'NN'),
#  ('classic', 'JJ'),
#  ('use', 'NN'),
#  ('wordit', 'NN'),
#  ('called', 'VBN'),
#  ('oz', 'NN'),
#  ('nickname', 'NN'),
#  ('given', 'VBN'),
#  ('oswald', 'JJ'),
#  ('maximum', 'JJ'),
#  ('security', 'NN'),
#  ('state', 'NN'),
#  ('penitentary', 'JJ'),
#  ('focus', 'NN'),
#  ('mainly', 'RB'),
#  ('emerald', 'VBZ'),
#  ('city', 'NN'),
#  ('experimental', 'JJ'),
#  ('section', 'NN'),
#  ('prison', 'NN'),
#  ('cell', 'NN'),
#  ('glass', 'NN'),
#  ('front', 'JJ'),
#  ('face', 'NN'),
#  ('inwards', 'NNS'),
#  ('privacy', 'VBP'),
#  ('high', 'JJ'),
#  ('agenda', 'NN'),
#  ('em', 'VBP'),
#  ('city', 'NN'),
#  ('home', 'NN'),
#  ('manyaryans', 'NNS'),
#  ('muslim', 'VBP'),
#  ('gangsta', 'JJ'),
#  ('latino', 'NN'),
#  ('christian', 'JJ'),
#  ('italian', 'JJ'),
#  ('irish', 'JJ'),
#  ('moreso', 'NN'),
#  ('scuffle', 'VBD'),
#  ('death', 'NN'),
#  ('stare', 'NN'),
#  ('dodgy', 'VBZ'),
#  ('dealing', 'VBG'),
#  ('shady', 'JJ'),
#  ('agreement', 'NN'),
#  ('never', 'RB'),
#  ('far', 'RB'),
#  ('awayi', 'JJ'),
#  ('would', 'MD'),
#  ('say', 'VB'),
#  ('main', 'JJ'),
#  ('appeal', 'NN'),
#  ('show', 'NN'),
#  ('due', 'JJ'),
#  ('fact', 'NN'),
#  ('go', 'VB'),
#  ('show', 'NN'),
#  ('wouldnt', 'WRB'),
#  ('dare', 'NN'),
#  ('forget', 'VB'),
#  ('pretty', 'JJ'),
#  ('picture', 'NN'),
#  ('painted', 'VBN'),
#  ('mainstream', 'JJ'),
#  ('audience', 'NN'),
#  ('forget', 'NN'),
#  ('charm', 'NN'),
#  ('forget', 'NN'),
#  ('romanceoz', 'NN'),
#  ('doesnt', 'NN'),
#  ('mess', 'NN'),
#  ('around', 'IN'),
#  ('first', 'JJ'),
#  ('episode', 'NN'),
#  ('ever', 'RB'),
#  ('saw', 'VBD'),
#  ('struck', 'JJ'),
#  ('nasty', 'JJ'),
#  ('surreal', 'NN'),
#  ('couldnt', 'NNS'),
#  ('say', 'VBP'),
#  ('ready', 'JJ'),
#  ('watched', 'VBN'),
#  ('developed', 'JJ'),
#  ('taste', 'NN'),
#  ('oz', 'NN'),
#  ('got', 'VBD'),
#  ('accustomed', 'JJ'),
#  ('high', 'JJ'),
#  ('level', 'NN'),
#  ('graphic', 'JJ'),
#  ('violence', 'NN'),
#  ('violence', 'NN'),
#  ('injustice', 'NN'),
#  ('crooked', 'VBD'),
#  ('guard', 'NN'),
#  ('wholl', 'NN'),
#  ('sold', 'VBN'),
#  ('nickel', 'JJ'),
#  ('inmate', 'NN'),
#  ('wholl', 'NN'),
#  ('kill', 'NN'),
#  ('order', 'NN'),
#  ('get', 'VB'),
#  ('away', 'RB'),
#  ('well', 'RB'),
#  ('mannered', 'JJ'),
#  ('middle', 'JJ'),
#  ('class', 'NN'),
#  ('inmate', 'NN'),
#  ('turned', 'VBD'),
#  ('prison', 'JJ'),
#  ('bitch', 'NN'),
#  ('due', 'JJ'),
#  ('lack', 'NN'),
#  ('street', 'NN'),
#  ('skill', 'JJ'),
#  ('prison', 'NN'),
#  ('experience', 'NN'),
#  ('watching', 'VBG'),
#  ('oz', 'NN'),
#  ('may', 'MD'),
#  ('become', 'VB'),
#  ('comfortable', 'JJ'),
#  ('uncomfortable', 'JJ'),
#  ('viewingthats', 'NNS'),
#  ('get', 'VBP'),
#  ('touch', 'JJ'),
#  ('darker', 'NN'),
#  ('side', 'NN')]

# %%
spacy.explain('CD')
# Out:
# 'cardinal number'

# %%
spacy.explain('VBD')
# Out:
# 'verb, past tense'

# %%
def displacy_render(text):
    doc = nlp(text)
    displacy.render(doc, style="dep", jupyter=True, options={"distance": 110,"compact":True})
    return None

#df['procss'].apply(displacy_render)
displacy_render(df['procss'][0])
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0b003d8897e1447f9df6e1b81d4569d4-0" class="displacy" width="19190" height="1017.0" direction="ltr" style="max-width: none; height: 1017.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">reviewer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">mentioned</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">watching</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">oz</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">episode</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">ll</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">hooked</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">right</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">exactly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">happened</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">methe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">thing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">struck</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">oz</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">brutality</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">unflinching</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">scene</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="2360">violence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2360">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="2470">set</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2470">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="2580">right</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2580">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">word</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="2800">go</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="2910">trust</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2910">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="3020">show</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3020">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">faint</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="3240">hearted</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3240">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="927.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">timid</tspan>
#     <tspan class="displacy-tag" dy="2em" fill=

# %%
options={'distance':110,"compact":True,"color":"black","bg":"white","font":"time"}
def displacy_render(text):
    doc = nlp(text)
    displacy.render(doc, style="dep", jupyter=True, options=options)
    return None
displacy_render(df['review'][0])
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d49fd07bba2e40d08348bbf1974535db-0" class="displacy" width="33820" height="632.0" direction="ltr" style="max-width: none; height: 632.0px; color: black; background: white; font-family: time; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">other</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">reviewers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">mentioned</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">after</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">watching</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">just</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">oz</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">episode</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">ll</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">hooked</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">they</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">right</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="2360">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2360">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="2470">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2470">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="2580">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2580">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">exactly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="2800">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="2910">happened</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2910">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="3020">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3020">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">methe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="3240">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3240">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="542.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">thing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NOUN</tspan>
# </tex
