# %% [markdown]
# # Practical 3
# ## Tokenization: Split the text sentence/paragraph/Data set and generate Tokens.

# %%
import nlp_lib #https://github.com/Sh1vam/nlp_lib
from nlp_lib import *

# %%
df=pd.read_csv("SMSSpamCollection.tsv",sep='\t')
df.columns = ['label', 'text']

# %%
df.head()
# Out:
#   label                                               text
# 0  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 1   ham  Nah I don't think he goes to usf, he lives aro...
# 2   ham  Even my brother is not like to speak with me. ...
# 3   ham                I HAVE A DATE ON SUNDAY WITH WILL!!
# 4   ham  As per your request 'Melle Melle (Oru Minnamin...

# %% [markdown]
# ### Lower Casing

# %%
df['text']=df['text'].str.lower()

# %%
df.head()
# Out:
#   label                                               text
# 0  spam  free entry in 2 a wkly comp to win fa cup fina...
# 1   ham  nah i don't think he goes to usf, he lives aro...
# 2   ham  even my brother is not like to speak with me. ...
# 3   ham                i have a date on sunday with will!!
# 4   ham  as per your request 'melle melle (oru minnamin...

# %% [markdown]
# ### Removing HTML Tags

# %%
df['text']=df['text'].apply(remove_html_tags)
df.head()
# Out:
#   label                                               text
# 0  spam  free entry in 2 a wkly comp to win fa cup fina...
# 1   ham  nah i don't think he goes to usf, he lives aro...
# 2   ham  even my brother is not like to speak with me. ...
# 3   ham                i have a date on sunday with will!!
# 4   ham  as per your request 'melle melle (oru minnamin...

# %% [markdown]
# ### Removing URLs

# %%
df['text']=df['text'].apply(remove_url)
df.head()
# Out:
#   label                                               text
# 0  spam  free entry in 2 a wkly comp to win fa cup fina...
# 1   ham  nah i don't think he goes to usf, he lives aro...
# 2   ham  even my brother is not like to speak with me. ...
# 3   ham                i have a date on sunday with will!!
# 4   ham  as per your request 'melle melle (oru minnamin...

# %% [markdown]
# ### Removing Punctuations

# %%
df['text']=df['text'].apply(remove_punctuations)
df.head()
# Out:
#   label                                               text
# 0  spam  free entry in 2 a wkly comp to win fa cup fina...
# 1   ham  nah i dont think he goes to usf he lives aroun...
# 2   ham  even my brother is not like to speak with me t...
# 3   ham                  i have a date on sunday with will
# 4   ham  as per your request melle melle oru minnaminun...

# %% [markdown]
# ### Removing Special Characters

# %%
df['text']=df['text'].apply(removes_specials)
df.head()
# Out:
#   label                                               text
# 0  spam  free entry in 2 a wkly comp to win fa cup fina...
# 1   ham  nah i dont think he goes to usf he lives aroun...
# 2   ham  even my brother is not like to speak with me t...
# 3   ham                  i have a date on sunday with will
# 4   ham  as per your request melle melle oru minnaminun...

# %% [markdown]
# ### Removing Non-Printable Characters

# %%
df['text']=df['text'].apply(removes_non_printables)
df.head()
# Out:
#   label                                               text
# 0  spam  free entry in 2 a wkly comp to win fa cup fina...
# 1   ham  nah i dont think he goes to usf he lives aroun...
# 2   ham  even my brother is not like to speak with me t...
# 3   ham                  i have a date on sunday with will
# 4   ham  as per your request melle melle oru minnaminun...

# %% [markdown]
# ### Removing Stop Words

# %%
df['stopwords_removed']=df['text'].apply(remove_stopwords)
df.head()
# Out:
#   label                                               text  \
# 0  spam  free entry in 2 a wkly comp to win fa cup fina...
# 1   ham  nah i dont think he goes to usf he lives aroun...
# 2   ham  even my brother is not like to speak with me t...
# 3   ham                  i have a date on sunday with will
# 4   ham  as per your request melle melle oru minnaminun...
#
#                                    stopwords_removed
# 0  free entry 2 wkly comp win fa cup final tkts 2...
# 1        nah dont think goes usf lives around though
# 2     even brother like speak treat like aids patent
# 3                                        date sunday
# 4  per request melle melle oru minnaminunginte nu...

# %% [markdown]
# ### Text Tokenization

# %%
def tokenized_text(text):
    if pd.isnull(text):  
        return np.nan
    return nltk.word_tokenize(text)
df['tokenized']=df['stopwords_removed'].apply(tokenized_text)
df.head()
# Out:
#   label                                               text  \
# 0  spam  free entry in 2 a wkly comp to win fa cup fina...
# 1   ham  nah i dont think he goes to usf he lives aroun...
# 2   ham  even my brother is not like to speak with me t...
# 3   ham                  i have a date on sunday with will
# 4   ham  as per your request melle melle oru minnaminun...
#
#                                    stopwords_removed  \
# 0  free entry 2 wkly comp win fa cup final tkts 2...
# 1        nah dont think goes usf lives around though
# 2     even brother like speak treat like aids patent
# 3                                        date sunday
# 4  per request melle melle oru minnaminunginte nu...
#
#                                            tokenized
# 0  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goes, usf, lives, around, t...
# 2  [even, brother, like, speak, treat, like, aids...
# 3                                     [date, sunday]
# 4  [per, request, melle, melle, oru, minnaminungi...

# %% [markdown]
# ### Doing Stemming

# %%
df['porter_stemmed']=df['tokenized'].apply(porter_stemming)
df.head()
# Out:
#   label                                               text  \
# 0  spam  free entry in 2 a wkly comp to win fa cup fina...
# 1   ham  nah i dont think he goes to usf he lives aroun...
# 2   ham  even my brother is not like to speak with me t...
# 3   ham                  i have a date on sunday with will
# 4   ham  as per your request melle melle oru minnaminun...
#
#                                    stopwords_removed  \
# 0  free entry 2 wkly comp win fa cup final tkts 2...
# 1        nah dont think goes usf lives around though
# 2     even brother like speak treat like aids patent
# 3                                        date sunday
# 4  per request melle melle oru minnaminunginte nu...
#
#                                            tokenized  \
# 0  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goes, usf, lives, around, t...
# 2  [even, brother, like, speak, treat, like, aids...
# 3                                     [date, sunday]
# 4  [per, request, melle, melle, oru, minnaminungi...
#
#                                       porter_stemmed
# 0  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goe, usf, live, around, tho...
# 2  [even, brother, like, speak, treat, like, aid,...
# 3                                     [date, sunday]
# 4  [per, request, mell, mell, oru, minnaminungint...

# %%
df['lancaster_stemmed']=df['tokenized'].apply(lancaster_stemming)
df.head()
# Out:
#   label                                               text  \
# 0  spam  free entry in 2 a wkly comp to win fa cup fina...
# 1   ham  nah i dont think he goes to usf he lives aroun...
# 2   ham  even my brother is not like to speak with me t...
# 3   ham                  i have a date on sunday with will
# 4   ham  as per your request melle melle oru minnaminun...
#
#                                    stopwords_removed  \
# 0  free entry 2 wkly comp win fa cup final tkts 2...
# 1        nah dont think goes usf lives around though
# 2     even brother like speak treat like aids patent
# 3                                        date sunday
# 4  per request melle melle oru minnaminunginte nu...
#
#                                            tokenized  \
# 0  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goes, usf, lives, around, t...
# 2  [even, brother, like, speak, treat, like, aids...
# 3                                     [date, sunday]
# 4  [per, request, melle, melle, oru, minnaminungi...
#
#                                       porter_stemmed  \
# 0  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goe, usf, live, around, tho...
# 2  [even, brother, like, speak, treat, like, aid,...
# 3                                     [date, sunday]
# 4  [per, request, mell, mell, oru, minnaminungint...
#
#                                    lancaster_stemmed
# 0  [fre, entry, 2, wkly, comp, win, fa, cup, fin,...
# 1  [nah, dont, think, goe, usf, liv, around, though]
# 2        [ev, broth, lik, speak, tre, lik, aid, pat]
# 3                                      [dat, sunday]
# 4  [per, request, mel, mel, oru, minnaminungint, ...

# %%
df['snowball_stemmed']=df['tokenized'].apply(snowball_stemming)
df.head()
# Out:
#   label                                               text  \
# 0  spam  free entry in 2 a wkly comp to win fa cup fina...
# 1   ham  nah i dont think he goes to usf he lives aroun...
# 2   ham  even my brother is not like to speak with me t...
# 3   ham                  i have a date on sunday with will
# 4   ham  as per your request melle melle oru minnaminun...
#
#                                    stopwords_removed  \
# 0  free entry 2 wkly comp win fa cup final tkts 2...
# 1        nah dont think goes usf lives around though
# 2     even brother like speak treat like aids patent
# 3                                        date sunday
# 4  per request melle melle oru minnaminunginte nu...
#
#                                            tokenized  \
# 0  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goes, usf, lives, around, t...
# 2  [even, brother, like, speak, treat, like, aids...
# 3                                     [date, sunday]
# 4  [per, request, melle, melle, oru, minnaminungi...
#
#                                       porter_stemmed  \
# 0  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goe, usf, live, around, tho...
# 2  [even, brother, like, speak, treat, like, aid,...
# 3                                     [date, sunday]
# 4  [per, request, mell, mell, oru, minnaminungint...
#
#                                    lancaster_stemmed  \
# 0  [fre, entry, 2, wkly, comp, win, fa, cup, fin,...
# 1  [nah, dont, think, goe, usf, liv, around, though]
# 2        [ev, broth, lik, speak, tre, lik, aid, pat]
# 3                                      [dat, sunday]
# 4  [per, request, mel, mel, oru, minnaminungint, ...
#
#                                     snowball_stemmed
# 0  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goe, usf, live, around, tho...
# 2  [even, brother, like, speak, treat, like, aid,...
# 3                                     [date, sunday]
# 4  [per, request, mell, mell, oru, minnaminungint...

# %%
df['regexp_stemmed']=df['tokenized'].apply(regexp_stemming)
df.head()
# Out:
#   label                                               text  \
# 0  spam  free entry in 2 a wkly comp to win fa cup fina...
# 1   ham  nah i dont think he goes to usf he lives aroun...
# 2   ham  even my brother is not like to speak with me t...
# 3   ham                  i have a date on sunday with will
# 4   ham  as per your request melle melle oru minnaminun...
#
#                                    stopwords_removed  \
# 0  free entry 2 wkly comp win fa cup final tkts 2...
# 1        nah dont think goes usf lives around though
# 2     even brother like speak treat like aids patent
# 3                                        date sunday
# 4  per request melle melle oru minnaminunginte nu...
#
#                                            tokenized  \
# 0  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goes, usf, lives, around, t...
# 2  [even, brother, like, speak, treat, like, aids...
# 3                                     [date, sunday]
# 4  [per, request, melle, melle, oru, minnaminungi...
#
#                                       porter_stemmed  \
# 0  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goe, usf, live, around, tho...
# 2  [even, brother, like, speak, treat, like, aid,...
# 3                                     [date, sunday]
# 4  [per, request, mell, mell, oru, minnaminungint...
#
#                                    lancaster_stemmed  \
# 0  [fre, entry, 2, wkly, comp, win, fa, cup, fin,...
# 1  [nah, dont, think, goe, usf, liv, around, though]
# 2        [ev, broth, lik, speak, tre, lik, aid, pat]
# 3                                      [dat, sunday]
# 4  [per, request, mel, mel, oru, minnaminungint, ...
#
#                                     snowball_stemmed  \
# 0  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goe, usf, live, around, tho...
# 2  [even, brother, like, speak, treat, like, aid,...
# 3                                     [date, sunday]
# 4  [per, request, mell, mell, oru, minnaminungint...
#
#                                       regexp_stemmed
# 0  [fre, entry, 2, wkly, comp, win, fa, cup, fina...
# 1  [nah, dont, think, goe, usf, live, around, tho...
# 2  [even, brother, lik, speak, treat, lik, aid, p...
# 3                                      [dat, sunday]
# 4  [per, request, mell, mell, oru, minnaminungint...

# %% [markdown]
# ### Applying Lemmatization

# %%
df['lemmatized']=df['tokenized'].apply(wordnet_lemmatizing)
df.head()
# Out:
#   label                                               text  \
# 0  spam  free entry in 2 a wkly comp to win fa cup fina...
# 1   ham  nah i dont think he goes to usf he lives aroun...
# 2   ham  even my brother is not like to speak with me t...
# 3   ham                  i have a date on sunday with will
# 4   ham  as per your request melle melle oru minnaminun...
#
#                                    stopwords_removed  \
# 0  free entry 2 wkly comp win fa cup final tkts 2...
# 1        nah dont think goes usf lives around though
# 2     even brother like speak treat like aids patent
# 3                                        date sunday
# 4  per request melle melle oru minnaminunginte nu...
#
#                                            tokenized  \
# 0  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goes, usf, lives, around, t...
# 2  [even, brother, like, speak, treat, like, aids...
# 3                                     [date, sunday]
# 4  [per, request, melle, melle, oru, minnaminungi...
#
#                                       porter_stemmed  \
# 0  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goe, usf, live, around, tho...
# 2  [even, brother, like, speak, treat, like, aid,...
# 3                                     [date, sunday]
# 4  [per, request, mell, mell, oru, minnaminungint...
#
#                                    lancaster_stemmed  \
# 0  [fre, entry, 2, wkly, comp, win, fa, cup, fin,...
# 1  [nah, dont, think, goe, usf, liv, around, though]
# 2        [ev, broth, lik, speak, tre, lik, aid, pat]
# 3                                      [dat, sunday]
# 4  [per, request, mel, mel, oru, minnaminungint, ...
#
#                                     snowball_stemmed  \
# 0  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goe, usf, live, around, tho...
# 2  [even, brother, like, speak, treat, like, aid,...
# 3                                     [date, sunday]
# 4  [per, request, mell, mell, oru, minnaminungint...
#
#                                       regexp_stemmed  \
# 0  [fre, entry, 2, wkly, comp, win, fa, cup, fina...
# 1  [nah, dont, think, goe, usf, live, around, tho...
# 2  [even, brother, lik, speak, treat, lik, aid, p...
# 3                                      [dat, sunday]
# 4  [per, request, mell, mell, oru, minnaminungint...
#
#                                           lemmatized
# 0  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 1  [nah, dont, think, go, usf, life, around, though]
# 2  [even, brother, like, speak, treat, like, aid,...
# 3                                     [date, sunday]
# 4  [per, request, melle, melle, oru, minnaminungi...

# %%
df['procss']=df['lemmatized'].apply(list_joint)

# %%
df.head()
# Out:
#   label                                               text  \
# 0  spam  free entry in 2 a wkly comp to win fa cup fina...
# 1   ham  nah i dont think he goes to usf he lives aroun...
# 2   ham  even my brother is not like to speak with me t...
# 3   ham                  i have a date on sunday with will
# 4   ham  as per your request melle melle oru minnaminun...
#
#                                    stopwords_removed  \
# 0  free entry 2 wkly comp win fa cup final tkts 2...
# 1        nah dont think goes usf lives around though
# 2     even brother like speak treat like aids patent
# 3                                        date sunday
# 4  per request melle melle oru minnaminunginte nu...
#
#                                            tokenized  \
# 0  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goes, usf, lives, around, t...
# 2  [even, brother, like, speak, treat, like, aids...
# 3                                     [date, sunday]
# 4  [per, request, melle, melle, oru, minnaminungi...
#
#                                       porter_stemmed  \
# 0  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goe, usf, live, around, tho...
# 2  [even, brother, like, speak, treat, like, aid,...
# 3                                     [date, sunday]
# 4  [per, request, mell, mell, oru, minnaminungint...
#
#                                    lancaster_stemmed  \
# 0  [fre, entry, 2, wkly, comp, win, fa, cup, fin,...
# 1  [nah, dont, think, goe, usf, liv, around, though]
# 2        [ev, broth, lik, speak, tre, lik, aid, pat]
# 3                                      [dat, sunday]
# 4  [per, request, mel, mel, oru, minnaminungint, ...
#
#                                     snowball_stemmed  \
# 0  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 1  [nah, dont, think, goe, usf, live, around, tho...
# 2  [even, brother, like, speak, treat, like, aid,...
# 3                                     [date, sunday]
# 4  [per, request, mell, mell, oru, minnaminungint...
#
#                                       regexp_stemmed  \
# 0  [fre, entry, 2, wkly, comp, win, fa, cup, fina...
# 1  [nah, dont, think, goe, usf, live, around, tho...
# 2  [even, brother, lik, speak, treat, lik, aid, p...
# 3                                      [dat, sunday]
# 4  [per, request, mell, mell, oru, minnaminungint...
#
#                                           lemmatized  \
# 0  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 1  [nah, dont, think, go, usf, life, around, though]
# 2  [even, brother, like, speak, treat, like, aid,...
# 3                                     [date, sunday]
# 4  [per, request, melle, melle, oru, minnaminungi...
#
#                                               procss
# 0  free entry 2 wkly comp win fa cup final tkts 2...
# 1           nah dont think go usf life around though
# 2      even brother like speak treat like aid patent
# 3                                        date sunday
# 4  per request melle melle oru minnaminunginte nu...

# %%
a=word_pos_tag(df["procss"][0])
a
# Out:
# [('free', 'JJ'),
#  ('entry', 'NN'),
#  ('2', 'CD'),
#  ('wkly', 'JJ'),
#  ('comp', 'NN'),
#  ('win', 'VBP'),
#  ('fa', 'JJ'),
#  ('cup', 'NN'),
#  ('final', 'JJ'),
#  ('tkts', 'NN'),
#  ('21st', 'CD'),
#  ('may', 'MD'),
#  ('2005', 'CD'),
#  ('text', 'NN'),
#  ('fa', 'NN'),
#  ('87121', 'CD'),
#  ('receive', 'JJ'),
#  ('entry', 'NN'),
#  ('questionstd', 'NN'),
#  ('txt', 'NN'),
#  ('ratetcs', 'NN'),
#  ('apply', 'VBP'),
#  ('08452810075over18s', 'CD')]

# %%
b=get_wordnet_pos('JJ')
b
# Out:
# 'a'

# %%
df['pos_tagged']=df["procss"].apply(pos_tag)

# %%
spacy.explain('CD')
# Out:
# 'cardinal number'

# %%
spacy.explain('VBD')
# Out:
# 'verb, past tense'

# %%
def displacy_render(text):
    doc = nlp(text)
    displacy.render(doc, style="dep", jupyter=True, options={"distance": 110,"compact":True})
    return None

#df['procss'].apply(displacy_render)
displacy_render(df['procss'][0])
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="17485d9646ee4160b08e0503bf9e2b00-0" class="displacy" width="2580" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">free</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">entry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">2</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">wkly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">comp</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">win</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">fa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">cup</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">final</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">tkts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">21st</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">may</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">2005</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">text</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">fa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">87121</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">receive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">entry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">questionstd</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">txt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">ratetcs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2360">apply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2360">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2470">08452810075over18s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2470">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-17485d9646ee4160b08e0503bf9e2b00-0-0" stroke-width="2px" d="M62,222.0 62,203.66666666666666 151.0,203.66666666666666 151.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-17485d9646ee4160b08e0503bf9e2b00-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,224.0 L58,216.0 66,216.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-17485d9646ee4160b08e0503bf9e2b00-0-1" stroke-width="2px" d="M172,222.0 172,148.66666666666669 1040.0,148.66666666666669 1040.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-17485d9646ee4160b08e0503bf9e2b00-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M172,224.0 L168,216.0 176,216.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-17485d9646ee4160b08e0503bf9e2b00-0-2" stroke-width="2px" d="M282,222.0 282,185.33333333333334 484.0,185.33333333333334 484.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-17485d9646ee4160b08e0503bf9e2b00-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M282,224.0 L278,216.0 286,216.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-17485d9646ee4160b08e0503bf9e2b00-0-3" stroke-width="2px" d="M392,222.0 392,203.666666

# %%
options={'distance':110,"compact":True,"color":"black","bg":"white","font":"time"}
def displacy_render(text):
    doc = nlp(text)
    displacy.render(doc, style="dep", jupyter=True, options=options)
    return None
displacy_render(df['text'][0])
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9a17607bd2bf4d22a65f870368037fa9-0" class="displacy" width="3130" height="467.0" direction="ltr" style="max-width: none; height: 467.0px; color: black; background: white; font-family: time; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">free</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">entry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">2</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">wkly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">comp</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">win</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">fa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">cup</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">final</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">tkts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">21st</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">may</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">2005</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">text</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">fa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">87121</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2360">receive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2360">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2470">entry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2470">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2580">questionstd</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2580">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">txt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2800">ratetcs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2910">apply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2910">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="3020">08452810075over18s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3020">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9a17607bd2bf4d22a65f870368037fa9-0-0" stroke-width="2px" d="M62,332.0 62,313.6666666666667 145.0,313.6666666666667 145.0,332.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9a17607bd2bf4d22a65f870368037fa9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,334.0 L58,326.0 66,326.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9a17607bd2bf4d22a65f870368037fa9-0-1" stroke-width="2px" d="M172,332.0 172,22
